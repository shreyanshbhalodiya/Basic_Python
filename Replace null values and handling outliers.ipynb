# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Loading the data
import os
os.chdir("C:\\Users\\Shreyansh")

fram = pd.read_csv("framingham.csv")
fram
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %% [markdown]
# # so for calculating average only observations which has values are included all the cases which have null value are excluded
# # so formula for average is = total sum/ no. of obseravations which has values
# # Null values are excluded in denominator see count differs

# %%
#description of the data
fram.describe()
# Out:
#               male          age    education  currentSmoker   cigsPerDay  \
# count  4240.000000  4240.000000  4135.000000    4240.000000  4211.000000
# mean      0.429245    49.580189     1.979444       0.494104     9.005937
# std       0.495027     8.572942     1.019791       0.500024    11.922462
# min       0.000000    32.000000     1.000000       0.000000     0.000000
# 25%       0.000000    42.000000     1.000000       0.000000     0.000000
# 50%       0.000000    49.000000     2.000000       0.000000     0.000000
# 75%       1.000000    56.000000     3.000000       1.000000    20.000000
# max       1.000000    70.000000     4.000000       1.000000    70.000000
#
#             BPMeds  prevalentStroke  prevalentHyp     diabetes      totChol  \
# count  4187.000000      4240.000000   4240.000000  4240.000000  4190.000000
# mean      0.029615         0.005896      0.310613     0.025708   236.699523
# std       0.169544         0.076569      0.462799     0.158280    44.591284
# ...

# %%
fram.isnull()
# Out:
#        male    age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0     False  False      False          False       False   False
# 1     False  False      False          False       False   False
# 2     False  False      False          False       False   False
# 3     False  False      False          False       False   False
# 4     False  False      False          False       False   False
# ...     ...    ...        ...            ...         ...     ...
# 4235  False  False      False          False       False    True
# 4236  False  False      False          False       False   False
# 4237  False  False      False          False       False   False
# 4238  False  False      False          False       False   False
# 4239  False  False      False          False       False   False
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0               False         False     False    False  False  False  False
# ...

# %%
fram.shape
# Out:
# (4240, 16)

# %%
fram.sum()
# Out:
# male                 1820.00
# age                210220.00
# education            8185.00
# currentSmoker        2095.00
# cigsPerDay          37924.00
# BPMeds                124.00
# prevalentStroke        25.00
# prevalentHyp         1317.00
# diabetes              109.00
# totChol            991771.00
# sysBP              561183.50
# diaBP              351486.50
# BMI                108905.18
# heartRate          321651.00
# glucose            315724.00
# TenYearCHD            644.00
# dtype: float64

# %%
fram.isnull().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
#Getting the percentage of missing values
x = round(fram.isnull().sum()/len(fram)*100,2)
x[x>0]   # only the variable that contains missing values
# Out:
# education     2.48
# cigsPerDay    0.68
# BPMeds        1.25
# totChol       1.18
# BMI           0.45
# heartRate     0.02
# glucose       9.15
# dtype: float64

# %%
fram.describe()
# Out:
#               male          age    education  currentSmoker   cigsPerDay  \
# count  4240.000000  4240.000000  4135.000000    4240.000000  4211.000000
# mean      0.429245    49.580189     1.979444       0.494104     9.005937
# std       0.495027     8.572942     1.019791       0.500024    11.922462
# min       0.000000    32.000000     1.000000       0.000000     0.000000
# 25%       0.000000    42.000000     1.000000       0.000000     0.000000
# 50%       0.000000    49.000000     2.000000       0.000000     0.000000
# 75%       1.000000    56.000000     3.000000       1.000000    20.000000
# max       1.000000    70.000000     4.000000       1.000000    70.000000
#
#             BPMeds  prevalentStroke  prevalentHyp     diabetes      totChol  \
# count  4187.000000      4240.000000   4240.000000  4240.000000  4190.000000
# mean      0.029615         0.005896      0.310613     0.025708   236.699523
# std       0.169544         0.076569      0.462799     0.158280    44.591284
# ...

# %%
fram[fram.glucose.between(0 , 150)].describe()
# Out:
#               male          age    education  currentSmoker   cigsPerDay  \
# count  3802.000000  3802.000000  3707.000000    3802.000000  3777.000000
# mean      0.441610    49.574171     1.980308       0.492898     9.019328
# std       0.496644     8.593384     1.021829       0.500015    11.932805
# min       0.000000    32.000000     1.000000       0.000000     0.000000
# 25%       0.000000    42.000000     1.000000       0.000000     0.000000
# 50%       0.000000    49.000000     2.000000       0.000000     0.000000
# 75%       1.000000    56.000000     3.000000       1.000000    20.000000
# max       1.000000    70.000000     4.000000       1.000000    70.000000
#
#             BPMeds  prevalentStroke  prevalentHyp     diabetes      totChol  \
# count  3751.000000      3802.000000   3802.000000  3802.000000  3792.000000
# mean      0.029326         0.006049      0.310363     0.014992   236.876055
# std       0.168740         0.077553      0.462703     0.121537    44.751772
# ...

# %%
fram[fram.glucose.between(150 , 400)].describe()
# Out:
#             male        age  education  currentSmoker  cigsPerDay     BPMeds  \
# count  52.000000  52.000000  50.000000      52.000000   52.000000  52.000000
# mean    0.519231  54.846154   1.740000       0.326923    6.269231   0.076923
# std     0.504505   7.481702   1.006307       0.473665   10.177090   0.269069
# min     0.000000  36.000000   1.000000       0.000000    0.000000   0.000000
# 25%     0.000000  49.750000   1.000000       0.000000    0.000000   0.000000
# 50%     1.000000  55.500000   1.000000       0.000000    0.000000   0.000000
# 75%     1.000000  61.000000   2.000000       1.000000   15.000000   0.000000
# max     1.000000  67.000000   4.000000       1.000000   40.000000   1.000000
#
#        prevalentStroke  prevalentHyp   diabetes     totChol       sysBP  \
# count        52.000000     52.000000  52.000000   52.000000   52.000000
# mean          0.019231      0.480769   0.961538  243.269231  147.701923
# ...

# %%
fram[fram.glucose.between(200 , 400)].describe()
# Out:
#             male        age  education  currentSmoker  cigsPerDay     BPMeds  \
# count  34.000000  34.000000  33.000000      34.000000   34.000000  34.000000
# mean    0.470588  55.411765   1.606061       0.323529    6.500000   0.117647
# std     0.506640   6.546420   0.826869       0.474858   10.891337   0.327035
# min     0.000000  43.000000   1.000000       0.000000    0.000000   0.000000
# 25%     0.000000  52.000000   1.000000       0.000000    0.000000   0.000000
# 50%     0.000000  55.500000   1.000000       0.000000    0.000000   0.000000
# 75%     1.000000  61.000000   2.000000       1.000000   15.000000   0.000000
# max     1.000000  67.000000   3.000000       1.000000   40.000000   1.000000
#
#        prevalentStroke  prevalentHyp  diabetes     totChol       sysBP  \
# count        34.000000     34.000000      34.0   34.000000   34.000000
# mean          0.029412      0.558824       1.0  251.323529  153.088235
# ...

# %%
fram[fram['glucose'].isnull()].describe()
# Out:
#              male        age  education  currentSmoker  cigsPerDay  \
# count  388.000000  388.00000  380.00000     388.000000  384.000000
# mean     0.296392   49.00000    2.00000       0.528351    9.250000
# std      0.457255    8.31797    0.99868       0.499840   12.012396
# min      0.000000   34.00000    1.00000       0.000000    0.000000
# 25%      0.000000   42.00000    1.00000       0.000000    0.000000
# 50%      0.000000   48.00000    2.00000       1.000000    3.000000
# 75%      1.000000   55.00000    3.00000       1.000000   20.000000
# max      1.000000   69.00000    4.00000       1.000000   60.000000
#
#            BPMeds  prevalentStroke  prevalentHyp    diabetes     totChol  \
# count  386.000000       388.000000    388.000000  388.000000  348.000000
# mean     0.025907         0.002577      0.288660    0.010309  233.635057
# std      0.159063         0.050767      0.453724    0.101140   42.485551
# ...

# %%
fram[fram.diabetes == 1].describe()
# Out:
#              male         age   education  currentSmoker  cigsPerDay  \
# count  109.000000  109.000000  106.000000     109.000000  109.000000
# mean     0.477064   54.926606    1.735849       0.357798    6.293578
# std      0.501781    7.576409    0.988524       0.481566    9.819956
# min      0.000000   36.000000    1.000000       0.000000    0.000000
# 25%      0.000000   49.000000    1.000000       0.000000    0.000000
# 50%      0.000000   55.000000    1.000000       0.000000    0.000000
# 75%      1.000000   62.000000    2.000000       1.000000   15.000000
# max      1.000000   68.000000    4.000000       1.000000   40.000000
#
#            BPMeds  prevalentStroke  prevalentHyp  diabetes     totChol  \
# count  107.000000       109.000000    109.000000     109.0  108.000000
# mean     0.084112         0.009174      0.532110       1.0  247.759259
# std      0.278862         0.095783      0.501273       0.0   57.314491
# ...

# %%
fram[fram.diabetes == 0].describe()
# Out:
#               male          age    education  currentSmoker   cigsPerDay  \
# count  4131.000000  4131.000000  4029.000000    4131.000000  4102.000000
# mean      0.427984    49.439119     1.985853       0.497700     9.078011
# std       0.494846     8.553343     1.019935       0.500055    11.965905
# min       0.000000    32.000000     1.000000       0.000000     0.000000
# 25%       0.000000    42.000000     1.000000       0.000000     0.000000
# 50%       0.000000    49.000000     2.000000       0.000000     0.000000
# 75%       1.000000    56.000000     3.000000       1.000000    20.000000
# max       1.000000    70.000000     4.000000       1.000000    70.000000
#
#             BPMeds  prevalentStroke  prevalentHyp  diabetes      totChol  \
# count  4080.000000      4131.000000   4131.000000    4131.0  4082.000000
# mean      0.028186         0.005810      0.304769       0.0   236.406908
# std       0.165525         0.076009      0.460365       0.0    44.176378
# ...

# %%
x1 = fram[fram['glucose'].isnull()]
y = x1[x1.diabetes == 1 ] 
y['glucose'] = 170.3333
y
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 247      0   40        2.0              1        20.0     0.0
# 294      0   47        1.0              1        25.0     0.0
# 2570     1   47        3.0              0         0.0     0.0
# 3051     0   50        3.0              1         9.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 247                 0             0         1      NaN  114.0   65.0  21.19
# ...

# %%
fram[fram['glucose'].isnull()][fram[fram['glucose'].isnull()].diabetes == 1]['glucose']= 170.3333

# %%
fram[fram['glucose'].isnull()][fram[fram['glucose'].isnull()].diabetes == 1]
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 247      0   40        2.0              1        20.0     0.0
# 294      0   47        1.0              1        25.0     0.0
# 2570     1   47        3.0              0         0.0     0.0
# 3051     0   50        3.0              1         9.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 247                 0             0         1      NaN  114.0   65.0  21.19
# 294                 0             1         1    258.0  195.0   90.0    NaN
# 2570                0             0         1    199.0  161.0  102.0  29.17
# 3051                0             0         1    210.0  134.0   80.0  18.26
#
#       heartRate  glucose  TenYearCHD
# 247        61.0      NaN           1
# 294        86.0      NaN           1
# 2570       58.0      NaN           0
# 3051       64.0      NaN           0

# %%
x[x.diabetes == 0 ]
# Out:
# 0.0

# %%
x0 = fram[fram['glucose'].isnull()]
y0 = x0[x0.diabetes == 0 ] 
y0['glucose'] = 79.48
y0
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 14       0   39        2.0              1         9.0     0.0
# 21       0   43        1.0              0         0.0     0.0
# 26       0   60        1.0              0         0.0     0.0
# 42       0   52        1.0              0         0.0     1.0
# 54       0   39        2.0              1        20.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4170     0   41        2.0              1         5.0     0.0
# ...

# %%
df_row = pd.concat([y, y0])
df_row
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 247      0   40        2.0              1        20.0     0.0
# 294      0   47        1.0              1        25.0     0.0
# 2570     1   47        3.0              0         0.0     0.0
# 3051     0   50        3.0              1         9.0     0.0
# 14       0   39        2.0              1         9.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4170     0   41        2.0              1         5.0     0.0
# 4208     0   51        1.0              1         9.0     0.0
# 4229     0   51        3.0              1        20.0     0.0
# 4230     0   56        1.0              1         3.0     0.0
# 4236     0   44        1.0              1        15.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 247                 0             0         1      NaN  114.0   65.0  21.19
# ...

# %%
df_row.isnull().sum()
# Out:
# male                0
# age                 0
# education           8
# currentSmoker       0
# cigsPerDay          4
# BPMeds              2
# prevalentStroke     0
# prevalentHyp        0
# diabetes            0
# totChol            40
# sysBP               0
# diaBP               0
# BMI                 5
# heartRate           0
# glucose             0
# TenYearCHD          0
# dtype: int64

# %%
notnull = fram[fram['glucose'].notnull()]

# %%
notnull.describe()
# Out:
#               male          age    education  currentSmoker   cigsPerDay  \
# count  3852.000000  3852.000000  3755.000000    3852.000000  3827.000000
# mean      0.442627    49.638629     1.977364       0.490654     8.981448
# std       0.496762     8.597086     1.022011       0.499978    11.914705
# min       0.000000    32.000000     1.000000       0.000000     0.000000
# 25%       0.000000    42.000000     1.000000       0.000000     0.000000
# 50%       0.000000    49.000000     2.000000       0.000000     0.000000
# 75%       1.000000    57.000000     3.000000       1.000000    20.000000
# max       1.000000    70.000000     4.000000       1.000000    70.000000
#
#             BPMeds  prevalentStroke  prevalentHyp     diabetes      totChol  \
# count  3801.000000      3852.000000   3852.000000  3852.000000  3842.000000
# mean      0.029992         0.006231      0.312825     0.027259   236.977095
# std       0.170588         0.078698      0.463704     0.162857    44.772060
# ...

# %%
notnull.isnull().sum()
# Out:
# male                0
# age                 0
# education          97
# currentSmoker       0
# cigsPerDay         25
# BPMeds             51
# prevalentStroke     0
# prevalentHyp        0
# diabetes            0
# totChol            10
# sysBP               0
# diaBP               0
# BMI                14
# heartRate           1
# glucose             0
# TenYearCHD          0
# dtype: int64

# %%
gram = pd.concat([df_row ,notnull ])
gram.describe()
# Out:
#               male          age    education  currentSmoker   cigsPerDay  \
# count  4240.000000  4240.000000  4135.000000    4240.000000  4211.000000
# mean      0.429245    49.580189     1.979444       0.494104     9.005937
# std       0.495027     8.572942     1.019791       0.500024    11.922462
# min       0.000000    32.000000     1.000000       0.000000     0.000000
# 25%       0.000000    42.000000     1.000000       0.000000     0.000000
# 50%       0.000000    49.000000     2.000000       0.000000     0.000000
# 75%       1.000000    56.000000     3.000000       1.000000    20.000000
# max       1.000000    70.000000     4.000000       1.000000    70.000000
#
#             BPMeds  prevalentStroke  prevalentHyp     diabetes      totChol  \
# count  4187.000000      4240.000000   4240.000000  4240.000000  4190.000000
# mean      0.029615         0.005896      0.310613     0.025708   236.699523
# std       0.169544         0.076569      0.462799     0.158280    44.591284
# ...

# %% [markdown]
# ### we can clearly see that mean is same because of lower number of observations but standard deviation differs

# %%
gram.isnull().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose              0
# TenYearCHD           0
# dtype: int64

# %%
g = gram[gram['education'].notnull()]
g
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 247      0   40        2.0              1        20.0     0.0
# 294      0   47        1.0              1        25.0     0.0
# 2570     1   47        3.0              0         0.0     0.0
# 3051     0   50        3.0              1         9.0     0.0
# 14       0   39        2.0              1         9.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 247                 0             0         1      NaN  114.0   65.0  21.19
# ...

# %%
n = gram[gram['education'].isnull()]
n['education'] = 2.5
n
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 499      0   60        2.5              0         0.0     0.0
# 1681     0   55        2.5              0         0.0     0.0
# 2846     1   50        2.5              1         9.0     0.0
# 2885     1   44        2.5              0         0.0     0.0
# 3290     0   65        2.5              0         0.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4012     0   40        2.5              1         9.0     0.0
# 4082     1   47        2.5              0         0.0     0.0
# ...

# %%
gram = pd.concat([g , n ])
gram.isnull().sum()
# Out:
# male                0
# age                 0
# education           0
# currentSmoker       0
# cigsPerDay         29
# BPMeds             53
# prevalentStroke     0
# prevalentHyp        0
# diabetes            0
# totChol            50
# sysBP               0
# diaBP               0
# BMI                19
# heartRate           1
# glucose             0
# TenYearCHD          0
# dtype: int64

# %%
ot = gram[gram['cigsPerDay'].isnull()]
ot['cigsPerDay'] = 9
ot
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 131      1   43        4.0              1           9     0.0
# 1347     0   58        4.0              1           9     0.0
# 1980     0   60        2.0              1           9     0.0
# 3579     1   42        1.0              1           9     0.0
# 139      1   49        4.0              1           9     0.0
# 1046     0   49        1.0              1           9     0.0
# 1292     1   42        3.0              1           9     0.0
# 1451     1   54        1.0              1           9     0.0
# ...

# %%
cpdnn = gram[gram['cigsPerDay'].notnull()]

# %%
gram = pd.concat([ot,cpdnn])
gram.isnull().sum()
# Out:
# male                0
# age                 0
# education           0
# currentSmoker       0
# cigsPerDay          0
# BPMeds             53
# prevalentStroke     0
# prevalentHyp        0
# diabetes            0
# totChol            50
# sysBP               0
# diaBP               0
# BMI                19
# heartRate           1
# glucose             0
# TenYearCHD          0
# dtype: int64

# %%
gram.describe()
# Out:
#               male          age    education  currentSmoker   cigsPerDay  \
# count  4240.000000  4240.000000  4240.000000    4240.000000  4240.000000
# mean      0.429245    49.580189     1.992335       0.494104     9.005896
# std       0.495027     8.572942     1.010327       0.500024    11.881610
# min       0.000000    32.000000     1.000000       0.000000     0.000000
# 25%       0.000000    42.000000     1.000000       0.000000     0.000000
# 50%       0.000000    49.000000     2.000000       0.000000     0.000000
# 75%       1.000000    56.000000     3.000000       1.000000    20.000000
# max       1.000000    70.000000     4.000000       1.000000    70.000000
#
#             BPMeds  prevalentStroke  prevalentHyp     diabetes      totChol  \
# count  4187.000000      4240.000000   4240.000000  4240.000000  4190.000000
# mean      0.029615         0.005896      0.310613     0.025708   236.699523
# std       0.169544         0.076569      0.462799     0.158280    44.591284
# ...

# %%
gram[gram.sysBP.between(200,300)].describe()
# Out:
#             male        age  education  currentSmoker  cigsPerDay     BPMeds  \
# count  44.000000  44.000000  44.000000      44.000000    44.00000  42.000000
# mean    0.227273  59.431818   1.659091       0.272727     4.75000   0.261905
# std     0.423915   5.707595   0.833686       0.450511     9.57255   0.445001
# min     0.000000  46.000000   1.000000       0.000000     0.00000   0.000000
# 25%     0.000000  55.000000   1.000000       0.000000     0.00000   0.000000
# 50%     0.000000  61.000000   1.000000       0.000000     0.00000   0.000000
# 75%     0.000000  64.000000   2.000000       1.000000     1.50000   0.750000
# max     1.000000  67.000000   4.000000       1.000000    43.00000   1.000000
#
#        prevalentStroke  prevalentHyp   diabetes     totChol       sysBP  \
# count             44.0     44.000000  44.000000   44.000000   44.000000
# mean               0.0      0.977273   0.204545  257.454545  213.897727
# ...

# %%
bp = gram[gram['BPMeds'].isnull()]
bp.describe()
# Out:
#             male        age  education  currentSmoker  cigsPerDay  BPMeds  \
# count  53.000000  53.000000  53.000000      53.000000   53.000000     0.0
# mean    0.283019  53.490566   1.867925       0.433962    8.169811     NaN
# std     0.454776   9.092733   1.074848       0.500363   12.220311     NaN
# min     0.000000  36.000000   1.000000       0.000000    0.000000     NaN
# 25%     0.000000  45.000000   1.000000       0.000000    0.000000     NaN
# 50%     0.000000  56.000000   1.000000       0.000000    0.000000     NaN
# 75%     1.000000  60.000000   3.000000       1.000000   15.000000     NaN
# max     1.000000  68.000000   4.000000       1.000000   50.000000     NaN
#
#        prevalentStroke  prevalentHyp   diabetes     totChol       sysBP  \
# count        53.000000     53.000000  53.000000   52.000000   53.000000
# mean          0.018868      0.415094   0.037736  240.461538  137.320755
# std           0.137361      0.497454   0.192380   52.805771   25.453973
# ...

# %%
bph = bp[bp.sysBP.between(151,300)]
bph['BPMeds'] = 1
bph.head(2)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 395     0   65        2.0              0         0.0       1                0
# 797     0   59        4.0              0         0.0       1                0
#
#      prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 395             1         0    270.0  165.0   98.0  21.66       62.0     92.0
# 797             1         0    240.0  195.0  118.0  23.82       80.0     73.0
#
#      TenYearCHD
# 395           1
# 797           0

# %%
bpl = bp[bp.sysBP.between(0,150)]
bpl['BPMeds'] = 0
bph.head(2)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 395     0   65        2.0              0         0.0       0                0
# 797     0   59        4.0              0         0.0       0                0
#
#      prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 395             1         0    270.0  165.0   98.0  21.66       62.0     92.0
# 797             1         0    240.0  195.0  118.0  23.82       80.0     73.0
#
#      TenYearCHD
# 395           1
# 797           0

# %%
bpu = pd.concat([bph,bpl])

# %%
bpo = gram[gram['BPMeds'].notnull()]

# %%
gram = pd.concat([bpo,bpu])
gram.isnull().sum()
# Out:
# male                0
# age                 0
# education           0
# currentSmoker       0
# cigsPerDay          0
# BPMeds              0
# prevalentStroke     0
# prevalentHyp        0
# diabetes            0
# totChol            50
# sysBP               0
# diaBP               0
# BMI                19
# heartRate           1
# glucose             0
# TenYearCHD          0
# dtype: int64

# %%
gram.describe()
# Out:
#               male          age    education  currentSmoker   cigsPerDay  \
# count  4279.000000  4279.000000  4279.000000    4279.000000  4279.000000
# mean      0.427436    49.670951     1.993106       0.490301     8.944847
# std       0.494764     8.596191     1.013703       0.499964    11.869016
# min       0.000000    32.000000     1.000000       0.000000     0.000000
# 25%       0.000000    42.000000     1.000000       0.000000     0.000000
# 50%       0.000000    49.000000     2.000000       0.000000     0.000000
# 75%       1.000000    57.000000     3.000000       1.000000    20.000000
# max       1.000000    70.000000     4.000000       1.000000    70.000000
#
#             BPMeds  prevalentStroke  prevalentHyp     diabetes      totChol  \
# count  4279.000000      4279.000000   4279.000000  4279.000000  4229.000000
# mean      0.028979         0.005842      0.316896     0.026174   236.829274
# std       0.167766         0.076221      0.465321     0.159672    44.591929
# ...

# %% [markdown]
# ##  how to replace null values directly in file itself. No need to concat tables

# %%
gram.BMI.fillna(gram.BMI.mean() , inplace=True)

# %%
gram.totChol.fillna(gram.totChol.mean() , inplace=True)

# %%
gram.heartRate.fillna(gram.heartRate.mean() , inplace=True)

# %%
gram.isnull().sum()
# Out:
# male               0
# age                0
# education          0
# currentSmoker      0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# glucose            0
# TenYearCHD         0
# dtype: int64

# %%
gram.describe()
# Out:
#               male          age    education  currentSmoker   cigsPerDay  \
# count  4279.000000  4279.000000  4279.000000    4279.000000  4279.000000
# mean      0.427436    49.670951     1.993106       0.490301     8.944847
# std       0.494764     8.596191     1.013703       0.499964    11.869016
# min       0.000000    32.000000     1.000000       0.000000     0.000000
# 25%       0.000000    42.000000     1.000000       0.000000     0.000000
# 50%       0.000000    49.000000     2.000000       0.000000     0.000000
# 75%       1.000000    57.000000     3.000000       1.000000    20.000000
# max       1.000000    70.000000     4.000000       1.000000    70.000000
#
#             BPMeds  prevalentStroke  prevalentHyp     diabetes      totChol  \
# count  4279.000000      4279.000000   4279.000000  4279.000000  4279.000000
# mean      0.028979         0.005842      0.316896     0.026174   236.829274
# std       0.167766         0.076221      0.465321     0.159672    44.330574
# ...

# %% [markdown]
# # FINAL COMPARISION BEFORE N AFTER REPLACING NULL VALUES

# %%
fram.describe()
# Out:
#               male          age    education  currentSmoker   cigsPerDay  \
# count  4240.000000  4240.000000  4135.000000    4240.000000  4211.000000
# mean      0.429245    49.580189     1.979444       0.494104     9.005937
# std       0.495027     8.572942     1.019791       0.500024    11.922462
# min       0.000000    32.000000     1.000000       0.000000     0.000000
# 25%       0.000000    42.000000     1.000000       0.000000     0.000000
# 50%       0.000000    49.000000     2.000000       0.000000     0.000000
# 75%       1.000000    56.000000     3.000000       1.000000    20.000000
# max       1.000000    70.000000     4.000000       1.000000    70.000000
#
#             BPMeds  prevalentStroke  prevalentHyp     diabetes      totChol  \
# count  4187.000000      4240.000000   4240.000000  4240.000000  4190.000000
# mean      0.029615         0.005896      0.310613     0.025708   236.699523
# std       0.169544         0.076569      0.462799     0.158280    44.591284
# ...

# %% [markdown]
# # BELOW CODES ARE ROUGH WORK FOR PRACTICE

# %%
bram = fram.copy()

# %%
r = bram[bram['glucose'].isnull()]
r['glucose'] = 81.963655
r
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 14       0   39        2.0              1         9.0     0.0
# 21       0   43        1.0              0         0.0     0.0
# 26       0   60        1.0              0         0.0     0.0
# 42       0   52        1.0              0         0.0     1.0
# 54       0   39        2.0              1        20.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4170     0   41        2.0              1         5.0     0.0
# 4208     0   51        1.0              1         9.0     0.0
# ...

# %%
nn = bram[bram['glucose'].notnull()]

# %%
bram = pd.concat([r,nn])
bram.describe()
# Out:
#               male          age    education  currentSmoker   cigsPerDay  \
# count  4240.000000  4240.000000  4135.000000    4240.000000  4211.000000
# mean      0.429245    49.580189     1.979444       0.494104     9.005937
# std       0.495027     8.572942     1.019791       0.500024    11.922462
# min       0.000000    32.000000     1.000000       0.000000     0.000000
# 25%       0.000000    42.000000     1.000000       0.000000     0.000000
# 50%       0.000000    49.000000     2.000000       0.000000     0.000000
# 75%       1.000000    56.000000     3.000000       1.000000    20.000000
# max       1.000000    70.000000     4.000000       1.000000    70.000000
#
#             BPMeds  prevalentStroke  prevalentHyp     diabetes      totChol  \
# count  4187.000000      4240.000000   4240.000000  4240.000000  4190.000000
# mean      0.029615         0.005896      0.310613     0.025708   236.699523
# std       0.169544         0.076569      0.462799     0.158280    44.591284
# ...

# %%
fram['glucose'].between(50,100)
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4        True
#         ...
# 4235     True
# 4236    False
# 4237    False
# 4238     True
# 4239     True
# Name: glucose, Length: 4240, dtype: bool

# %%
df_all = pd.concat([fram['glucose'].between(50,100),fram['glucose'].between(150,200)], 
                   axis='columns', keys=['First', 'Second'])
df_all
# Out:
#       First  Second
# 0      True   False
# 1      True   False
# 2      True   False
# 3     False   False
# 4      True   False
# ...     ...     ...
# 4235   True   False
# 4236  False   False
# 4237  False   False
# 4238   True   False
# 4239   True   False
#
# [4240 rows x 2 columns]

# %%
fram[fram.glucose.between(50 , 100)].describe()
# Out:
#               male          age    education  currentSmoker   cigsPerDay  \
# count  3526.000000  3526.000000  3441.000000    3526.000000  3505.000000
# mean      0.441010    49.364152     1.991863       0.493193     9.078745
# std       0.496578     8.555243     1.021537       0.500025    11.965779
# min       0.000000    32.000000     1.000000       0.000000     0.000000
# 25%       0.000000    42.000000     1.000000       0.000000     0.000000
# 50%       0.000000    48.000000     2.000000       0.000000     0.000000
# 75%       1.000000    56.000000     3.000000       1.000000    20.000000
# max       1.000000    70.000000     4.000000       1.000000    70.000000
#
#             BPMeds  prevalentStroke  prevalentHyp     diabetes      totChol  \
# count  3479.000000      3526.000000   3526.000000  3526.000000  3519.000000
# mean      0.028169         0.005672      0.301475     0.005105   236.554987
# std       0.165479         0.075110      0.458963     0.071276    44.353633
# ...

# %%
fram['glucose'].describe()
# Out:
# count    3852.000000
# mean       81.963655
# std        23.954335
# min        40.000000
# 25%        71.000000
# 50%        78.000000
# 75%        87.000000
# max       394.000000
# Name: glucose, dtype: float64

# %%
df['two'].between(-0.5, 0.5, inclusive=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-75b3e0a0c750> in <module>
# ----> 1 df['two'].between(-0.5, 0.5, inclusive=False)
#
# NameError: name 'df' is not defined

# %%
fram[fram.glucose >50 and fram.glucose < 100]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-b0e51145df20> in <module>
# ----> 1 fram[fram.glucose >50 and fram.glucose < 100]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1477     def __nonzero__(self):
#    1478         raise ValueError(
# -> 1479             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1480             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1481         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
fram[fram.glucose > 100].count()
# Out:
# male               313
# age                313
# education          302
# currentSmoker      313
# cigsPerDay         309
# BPMeds             309
# prevalentStroke    313
# prevalentHyp       313
# diabetes           313
# totChol            310
# sysBP              313
# diaBP              313
# BMI                312
# heartRate          313
# glucose            313
# TenYearCHD         313
# dtype: int64

# %%
fram[fram.glucose > 100].describe()
# Out:
#              male         age   education  currentSmoker  cigsPerDay  \
# count  313.000000  313.000000  302.000000     313.000000  309.000000
# mean     0.453674   52.706070    1.824503       0.463259    7.825243
# std      0.498646    8.440394    1.017617       0.499447   11.126860
# min      0.000000   34.000000    1.000000       0.000000    0.000000
# 25%      0.000000   46.000000    1.000000       0.000000    0.000000
# 50%      0.000000   53.000000    1.000000       0.000000    0.000000
# 75%      1.000000   60.000000    2.000000       1.000000   15.000000
# max      1.000000   69.000000    4.000000       1.000000   50.000000
#
#            BPMeds  prevalentStroke  prevalentHyp    diabetes     totChol  \
# count  309.000000       313.000000    313.000000  313.000000  310.000000
# mean     0.051780         0.012780      0.434505    0.274760  242.048387
# std      0.221942         0.112502      0.496486    0.447108   48.559118
# ...
