# %%
import pandas as pd
import numpy as np

# %%
z = pd.read_csv("new_cases.csv")

# %%
z
# Out:
#            date   World  Afghanistan  Albania  Algeria  Andorra  Angola  \
# 0    2019-12-31      27          0.0      NaN      0.0      NaN     NaN
# 1    2020-01-01       0          0.0      NaN      0.0      NaN     NaN
# 2    2020-01-02       0          0.0      NaN      0.0      NaN     NaN
# 3    2020-01-03      17          0.0      NaN      0.0      NaN     NaN
# 4    2020-01-04       0          0.0      NaN      0.0      NaN     NaN
# ..          ...     ...          ...      ...      ...      ...     ...
# 235  2020-08-22  253593         38.0    152.0    409.0     21.0    29.0
# 236  2020-08-23  266468        105.0    156.0    401.0      0.0    24.0
# 237  2020-08-24  224489          0.0    152.0    392.0      0.0   103.0
# 238  2020-08-25  220031         71.0    178.0    398.0     15.0    51.0
# 239  2020-08-26  247181          1.0    154.0    370.0      0.0     0.0
#
#      Anguilla  Antigua and Barbuda  Argentina  ...  \
# ...

# %%
print(z.columns)
# Out:
# Index(['date', 'World', 'Afghanistan', 'Albania', 'Algeria', 'Andorra',
#        'Angola', 'Anguilla', 'Antigua and Barbuda', 'Argentina',
#        ...
#        'United States Virgin Islands', 'Uruguay', 'Uzbekistan', 'Vatican',
#        'Venezuela', 'Vietnam', 'Western Sahara', 'Yemen', 'Zambia',
#        'Zimbabwe'],
#       dtype='object', length=212)

# %%
x = z[['date','United States' , 'Brazil','India','Italy','Germany','Russia','United Kingdom','South Africa','Mexico','Panama','Peru','Saudi Arabia','Iraq','New Zealand','Australia']]

# %%
y = x.iloc[60:240]
y
# Out:
#            date  United States  Brazil    India  Italy  Germany  Russia  \
# 60   2020-02-29              6       0      0.0    238       10       0
# 61   2020-03-01              3       1      0.0    240       54       0
# 62   2020-03-02             20       0      0.0    561       18       0
# 63   2020-03-03             14       0      2.0    347       28       1
# 64   2020-03-04             22       0      1.0    466       39       1
# ..          ...            ...     ...      ...    ...      ...     ...
# 235  2020-08-22          49880   30355  69878.0    947     1134    4870
# 236  2020-08-23          44378   50032  69239.0   1071      782    4921
# 237  2020-08-24          34506   23421  61408.0   1209      711    4852
# 238  2020-08-25          38298   17078  60975.0    953     1278    4744
# 239  2020-08-26          38119   47134  67151.0    876     1576    4696
#
#      United Kingdom  South Africa  Mexico  Panama    Peru  Saudi Arabia  \
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # INDIA

# %%
fig , ax = plt.subplots(figsize=(24, 8))
ax.bar(y["date"] , y["India"])
plt.xticks( y['date'] , rotation ='vertical', size = 8 )
plt.xlabel(" date ")
plt.ylabel("daily new corona cases )")



plt.show()

# %%
fig , ax = plt.subplots(figsize=(24, 8))
ax.bar(q["date"] , q["India"], color = "r")
plt.xticks( q['date'] , rotation ='vertical', size = 8 )
plt.xlabel(" date ")
plt.ylabel("deaths ")



plt.show()

# %% [markdown]
# # USA

# %%
fig , ax = plt.subplots(figsize=(24, 8))
ax.bar(y["date"] , y["United States"])
plt.xticks( y['date'] , rotation ='vertical', size = 8 )
plt.xlabel(" date ")
plt.ylabel("daily new corona cases )")



plt.show()

# %%
fig , ax = plt.subplots(figsize=(24, 8))
ax.bar(q["date"] , q["United States"],color = "r")
plt.xticks( q['date'] , rotation ='vertical', size = 8 )
plt.xlabel(" date ")
plt.ylabel("deaths ")



plt.show()

# %% [markdown]
# # BRAZIL

# %%
fig , ax = plt.subplots(figsize=(24, 8))
ax.bar(y["date"] , y["Brazil"])
plt.xticks( y['date'] , rotation ='vertical', size = 8 )
plt.xlabel(" date ")
plt.ylabel("daily new corona cases )")



plt.show()

# %%
fig , ax = plt.subplots(figsize=(24, 8))
ax.bar(q["date"] , q["Brazil"],color = "r")
plt.xticks( q['date'] , rotation ='vertical', size = 8 )
plt.xlabel(" date ")
plt.ylabel("deaths ")



plt.show()

# %% [markdown]
# # UK

# %%
fig , ax = plt.subplots(figsize=(24, 8))
ax.bar(y["date"] , y["United Kingdom"])
plt.xticks( y['date'] , rotation ='vertical', size = 8 )
plt.xlabel(" date ")
plt.ylabel("daily new corona cases )")



plt.show()

# %%
fig , ax = plt.subplots(figsize=(24, 8))
ax.bar(q["date"] , q["United Kingdom"],color = "r")
plt.xticks( q['date'] , rotation ='vertical', size = 8 )
plt.xlabel(" date ")
plt.ylabel("deaths ")



plt.show()

# %% [markdown]
# # GERMANY

# %%
fig , ax = plt.subplots(figsize=(24, 8))
ax.bar(y["date"] , y["Germany"])
plt.xticks( y['date'] , rotation ='vertical', size = 8 )
plt.xlabel(" date ")
plt.ylabel("daily new corona cases )")



plt.show()

# %%
fig , ax = plt.subplots(figsize=(24, 8))
ax.bar(q["date"] , q["Germany"],color = "r")
plt.xticks( q['date'] , rotation ='vertical', size = 8 )
plt.xlabel(" date ")
plt.ylabel("deaths ")



plt.show()

# %% [markdown]
# # RUSSIA

# %%
fig , ax = plt.subplots(figsize=(24, 8))
ax.bar(y["date"] , y["Russia"])
plt.xticks( y['date'] , rotation ='vertical', size = 8 )
plt.xlabel(" date ")
plt.ylabel("daily new corona cases )")



plt.show()

# %%
fig , ax = plt.subplots(figsize=(24, 8))
ax.bar(q["date"] , q["Russia"],color = "r")
plt.xticks( q['date'] , rotation ='vertical', size = 8 )
plt.xlabel(" date ")
plt.ylabel("deaths ")



plt.show()

# %% [markdown]
# # PERU

# %%
fig , ax = plt.subplots(figsize=(24, 8))
ax.bar(y["date"] , y["Peru"])
plt.xticks( y['date'] , rotation ='vertical', size = 8 )
plt.xlabel(" date ")
plt.ylabel("daily new corona cases )")



plt.show()

# %%
fig , ax = plt.subplots(figsize=(24, 8))
ax.bar(q["date"] , q["Peru"],color = "r")
plt.xticks( q['date'] , rotation ='vertical', size = 8 )
plt.xlabel(" date ")
plt.ylabel("deaths ")



plt.show()

# %% [markdown]
# # NEW ZEALAND

# %%
fig , ax = plt.subplots(figsize=(24, 8))
ax.bar(y["date"] , y["New Zealand"],color = 'black')
plt.xticks( y['date'] , rotation ='vertical', size = 8 )
plt.xlabel(" date ")
plt.ylabel("daily new corona cases )")



plt.show()

# %% [markdown]
# # AUSTRALIA

# %%
fig , ax = plt.subplots(figsize=(24, 8))
ax.bar(y["date"] , y["Australia"] , color = "yellow")
plt.xticks( y['date'] , rotation ='vertical', size = 8 )
plt.xlabel(" date ")
plt.ylabel("daily new corona cases )")



plt.show()

# %% [markdown]
# # IRAQ

# %%
fig , ax = plt.subplots(figsize=(24, 8))
ax.bar(y["date"] , y["Iraq"])
plt.xticks( y['date'] , rotation ='vertical', size = 8 )
plt.xlabel(" date ")
plt.ylabel("daily new corona cases )")



plt.show()

# %%
fig , ax = plt.subplots(figsize=(24, 8))
ax.bar(q["date"] , q["Iraq"],color = "r")
plt.xticks( q['date'] , rotation ='vertical', size = 8 )
plt.xlabel(" date ")
plt.ylabel("deaths ")



plt.show()

# %% [markdown]
# # SAUDI ARABIA

# %%
fig , ax = plt.subplots(figsize=(24, 8))
ax.bar(y["date"] , y["Saudi Arabia"] , color = "pink")
plt.xticks( y['date'] , rotation ='vertical', size = 8 )
plt.xlabel(" date ")
plt.ylabel("daily new corona cases )")



plt.show()

# %% [markdown]
# # MEXICO

# %%
fig , ax = plt.subplots(figsize=(24, 8))
ax.bar(y["date"] , y["Mexico"])
plt.xticks( y['date'] , rotation ='vertical', size = 8 )
plt.xlabel(" date ")
plt.ylabel("daily new corona cases )")



plt.show()

# %%
fig , ax = plt.subplots(figsize=(24, 8))
ax.bar(q["date"] , q["Mexico"],color = "r")
plt.xticks( q['date'] , rotation ='vertical', size = 8 )
plt.xlabel(" date ")
plt.ylabel("deaths ")



plt.show()

# %%
df = pd.read_csv("new_deaths.csv")
df
# Out:
#            date  World  Afghanistan  Albania  Algeria  Andorra  Angola  \
# 0    2019-12-31      0          0.0      NaN      0.0      NaN     NaN
# 1    2020-01-01      0          0.0      NaN      0.0      NaN     NaN
# 2    2020-01-02      0          0.0      NaN      0.0      NaN     NaN
# 3    2020-01-03      0          0.0      NaN      0.0      NaN     NaN
# 4    2020-01-04      0          0.0      NaN      0.0      NaN     NaN
# ..          ...    ...          ...      ...      ...      ...     ...
# 235  2020-08-22   5916          0.0      2.0      7.0      0.0     1.0
# 236  2020-08-23   5633          2.0      5.0      6.0      0.0     1.0
# 237  2020-08-24   3322          0.0      5.0     11.0      0.0     2.0
# 238  2020-08-25   4541         10.0      4.0     11.0      0.0     4.0
# 239  2020-08-26   6322          0.0      5.0     10.0      0.0     0.0
#
#      Anguilla  Antigua and Barbuda  Argentina  ...  \
# 0         NaN                  NaN        NaN  ...
# ...

# %%
df = df.iloc[60:240]

# %%
q = df[['date','United States' , 'Brazil','India','Italy','Germany','Russia','United Kingdom','South Africa','Mexico','Panama','Peru','Saudi Arabia','Iraq','New Zealand','Australia']]

# %%
q
# Out:
#            date  United States  Brazil   India  Italy  Germany  Russia  \
# 60   2020-02-29              0       0     0.0      4        0       0
# 61   2020-03-01              1       0     0.0      8        0       0
# 62   2020-03-02              1       0     0.0      6        0       0
# 63   2020-03-03              4       0     0.0     17        0       0
# 64   2020-03-04              3       0     0.0     28        0       0
# ..          ...            ...     ...     ...    ...      ...     ...
# 235  2020-08-22           1151    1054   945.0      9        7      90
# 236  2020-08-23            956     892   912.0      3        2     121
# 237  2020-08-24            444     494   836.0      7        3      73
# 238  2020-08-25            473     565   848.0      4        5      65
# 239  2020-08-26           1207    1271  1059.0      4        3     120
#
#      United Kingdom  South Africa  Mexico  Panama   Peru  Saudi Arabia  Iraq  \
# ...

# %%
ds = pd.read_csv("datasets_507962_1091873_population_by_country_2020.csv")

# %%
ds
# Out:
#     Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 0                     China         1438207241        0.39 %     5540090
# 1                     India         1377233523        0.99 %    13586631
# 2             United States          330610570        0.59 %     1937734
# 3                 Indonesia          272931713        1.07 %     2898047
# 4                  Pakistan          219992900        2.00 %     4327022
# ..                      ...                ...           ...         ...
# 230              Montserrat               4991        0.06 %           3
# 231        Falkland Islands               3458        3.05 %         103
# 232                    Niue               1624        0.68 %          11
# 233                 Tokelau               1354        1.27 %          17
# 234                Holy See                801        0.25 %           2
#
#      Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# ...

# %%
a = ds.rename(columns = {"Country (or dependency)":"Country"})

# %%
a
# Out:
#               Country  Population (2020) Yearly Change  Net Change  \
# 0               China         1438207241        0.39 %     5540090
# 1               India         1377233523        0.99 %    13586631
# 2       United States          330610570        0.59 %     1937734
# 3           Indonesia          272931713        1.07 %     2898047
# 4            Pakistan          219992900        2.00 %     4327022
# ..                ...                ...           ...         ...
# 230        Montserrat               4991        0.06 %           3
# 231  Falkland Islands               3458        3.05 %         103
# 232              Niue               1624        0.68 %          11
# 233           Tokelau               1354        1.27 %          17
# 234          Holy See                801        0.25 %           2
#
#      Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 0                153          9388211       -348399.0        1.7       38
# ...
