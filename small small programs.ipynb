# %%
print("welcome to iron bank of davos's ATM happy to serve you ")
pwd = 1234
restart = ("Y")
bal = 75000.89
chances = 3
while chances>0:
    pin = int(input("Enter Your Password "))
    if pin == 1234:
        print("you have entered a coorect pin ")
        while restart not in ("n","no","NO","N"):
            print(" press 1 for withdrawal ")
            print("Press 2 for deposite ")
            print("press 3 check balance ")
            print(" press 4 for exit  ")
            a = int(input("Enter your choice here "))
              
            if a == 1:
                print("Enter the amount for your withdrawal ")
                withdrawl = float(int(input("Enter here ")))
                if withdrawl > bal:
                    print("Enter amount less than deposite you have  ")
                    break
                elif withdrawl == bal :
                    print("balance is zero ")
                elif withdrawl < bal:
                    new_bal = bal - withdrawl
                    print("your current balance is ", new_bal)
                restart = input("  ")
                if restart in ("n","no","NO","N"):
                    print("Thank you ")
                    break
                    
                    
            elif a==2:
                print("enter the amount of deposite ")
                deposite = float(input(" Enter here "))
                new_balance = deposite + bal-withdrawl
                print("your updated balance is " , new_balance )
                restart = input(" press y for going back to main menu and n for exit ")
                if restart in ("n","no","NO","N"):
                    print("Thank you ")
                    break
                    
                    
            elif a==3:
                curr_bal = bal + deposite - withdrawl
                print("your current balance is  ", curr_bal)
                restart = input(" press y for going back to main menu and n for exit ")
                if restart in ("n","no","NO","N"):
                    print("Thank you ")
                    break
            elif a==4:
                print("thank you ")
                break
            
            else:
                print('you have entered incorrect option ')
                break
                
    elif pin != 1234:
        print('you have entered incorrect pin you have two more chances to enter correct pin keep in mind only twwoooo chances')
        chances = chances - 1
        if chances == 0 :
            print("no more tries thank you ")
            break

# %%
import random

saaps = {99:18,95:57,87:23,65:48,55:7,42:3,34:17,18:9}
sidis = {5:47,12:29,28:54,35:49,62:77,79:94,81:91,87:92}

p1_name = input(" enter p1 name ")
p2_name = input(" enter p2 name ")

is_p1_turn = True
is_someone_won = False

p1_position = 0
p2_position = 0


def process_move(current_position , dice):
    print("current position",current_position , "dice",dice)
    new_position = current_position + dice
    
    if new_position in saaps:
        print("saap ne kaata",new_position)
        new_position = saaps[new_position]
        print("utar ke aya",new_position)
        
    if new_position in sidis:
        print("sidi se chada at",new_position)
        new_position = sidis[new_position]
        print("chad ke aya at",new_position)
    
    return new_position

while not is_someone_won:
    dice = random.randrange(1,7)
    if is_p1_turn:
        print(p1_name,"turn")
        p1_position = process_move(p1_position , dice)
        
    else:
        print(p2_name ,"turn")
        p2_position = process_move(p2_position , dice)
        
        
    if p1_position == 100 or p2_position == 100:
        is_someone_won = True
    if p1_position > 100:
        p1_position = p1_position - dice
    if p2_position > 100:
        p2_position = p2_position - dice
        
        
    if is_someone_won and is_p1_turn:
        print(p1_name,"WON")
    elif is_someone_won and not is_p1_turn:
        print(p2_name,"won")
    is_p1_turn = not is_p1_turn

# %%
import random
saaps = {99:18,95:57,87:23,65:48,55:7,42:3,34:17,18:9}
sidis = {5:47,12:29,28:54,35:49,62:77,79:94,81:91,87:92}
 
    
p1_name = input(" enter your name ")
p2_name = input(" enter your name ")

is_p1_turn = True
is_someone_won = False

p1_position = 0
p2_position = 0

def process_move(current_position , dice ):
    print("current position ", current_position , "dice ",dice )
    new_position = current_position + dice 
    
    if  new_position in saaps:
        print("saap ne kata  ", new_position)
        new_position = saaps[new_position]
        print(" utar ke aya " , new_position )
        
    if  new_position in sidis:
        print("sidi se chada ",new_position)
        new_position = sidis[new_position] 
        print("chad ke aya ", new_position)
        
        
    return new_position

while not is_someone_won:
    dice = random.randrange(1,7)
    if is_p1_turn:
        print(p1_name ,"turn")
        p1_position = process_move(p1_position , dice )
        
    else:
        print(p2_name , 'turn ')
        p2_position = process_move(p2_position , dice )
        
        
        
    if p1_position == 100 or p2_position == 100:
        is_someone_won = True
    if p1_position > 100:
        p1_position = p1_position - dice
    if p2_position > 100:
        p2_position = p1_position - dice
        
        
        
    if is_someone_won and is_p1_turn:
        print( p1_name , " WON" )
    if is_someone_won and not  is_p1_turn:
        print( p2_name , "WON ")
    is_p1_turn = not is_p1_turn
