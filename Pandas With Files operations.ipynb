# %%
#Reading data with Pandas using url

# %%
import pandas as pd
import numpy as np

# %%
csv_url =  "https://raw.githubusercontent.com/datasets/gdp/master/data/gdp.csv"
mp = pd.read_csv(csv_url).head()
mp
# Out:
#   Country Name Country Code  Year         Value
# 0   Arab World          ARB  1968  2.576068e+10
# 1   Arab World          ARB  1969  2.843420e+10
# 2   Arab World          ARB  1970  3.138550e+10
# 3   Arab World          ARB  1971  3.642691e+10
# 4   Arab World          ARB  1972  4.331606e+10

# %%
df = pd.read_csv('sales_data.csv - sales_data.csv','r')
df.head()
# Out:
#                                 Date,Day,Month,Yea  \
# 0                            2013-11-26,26,Novembe
# 1                            2015-11-26,26,Novembe
# 2                                 2014-03-23,23,Ma
# 3                                 2016-03-23,23,Ma
# 4  2014-05-15,15,May,2014,47,Adults (35-64),F,Aust
#
#                            ,Custome  \
# 0   ,2013,19,Youth (<25),M,Canada,B
# 1   ,2015,19,Youth (<25),M,Canada,B
# 2  ch,2014,49,Adults (35-64),M,Aust
# 3  ch,2016,49,Adults (35-64),M,Aust
# 4      alia,New South Wales,Accesso
#
#                                           _Age,Age_G  \
# 0                             itish Columbia,Accesso
# 1                             itish Columbia,Accesso
# 2                       alia,New South Wales,Accesso
# 3                       alia,New South Wales,Accesso
# 4  ies,Bike Racks,Hitch Rack - 4-Bike,4,45,120,23...
#
#                                          oup,Custome _Gende ,Count y,State,P  \
# ...

# %%
mp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  5 non-null      object
#  1   Country Code  5 non-null      object
#  2   Year          5 non-null      int64
#  3   Value         5 non-null      float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 288.0+ bytes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Date,Day,Month,Yea          113036 non-null  object
#  1   ,Custome                    111246 non-null  object
#  2   _Age,Age_G                  102840 non-null  object
#  3   oup,Custome                 85774 non-null   object
#  4   _Gende                      60280 non-null   object
#  5   ,Count                      29290 non-null   object
#  6   y,State,P                   8704 non-null    object
#  7   oduct_Catego                1888 non-null    object
#  8   y,Sub_Catego                312 non-null     object
#  9   y,P                         36 non-null      object
#  10  oduct,O                     0 non-null       float64
#  11  de                          0 non-null       float64
# ...

# %%
html_url = "https://www.basketball-reference.com/leagues/NBA_2019_per_game.html"

# using html url direct opening

# %%
data = pd.read_html(html_url)

# %%
len(data)
# Out:
# 1

# %%
import requests

html_url = "https://en.wikipedia.org/wiki/The_Simpsons"

# %%
r = requests.get(html_url)

wiki_tables = pd.read_html(r.text, header=0)

# %%
len(wiki_tables)
# Out:
# 27

# %%
simpsons = wiki_tables[1]

# %%
simpsons.head()
# Out:
#    Season Season.1  No. ofepisodes    Originally aired Originally aired.1  \
# 0  Season   Season  No. ofepisodes     Season premiere      Season finale
# 1  Season   Season  No. ofepisodes     Season premiere      Season finale
# 2       1  1989–90              13   December 17, 1989       May 13, 1990
# 3       2  1990–91              22    October 11, 1990      July 11, 1991
# 4       3  1991–92              24  September 19, 1991    August 27, 1992
#
#   Originally aired.2                 Viewership          Viewership.1  \
# 0     Time Slot (ET)  Avg. viewers(in millions)  Most watched episode
# 1     Time Slot (ET)  Avg. viewers(in millions)     Viewers(millions)
# 2     Sunday 8:30 pm                       27.8                  33.5
# 3   Thursday 8:00 pm                       24.4                  33.6
# 4   Thursday 8:00 pm                       21.8                  25.5
#
#               Viewership.2
# 0     Most watched episode
# 1            Episode Title
# ...

# %%
import pandas as pd
import numpy as anp
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# %%
df = pd.read_csv("winemag-data-130k-v2.csv")

# %%
df.shape
# Out:
# (129971, 14)

# %%
df.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
new = df.drop(columns = ["Unnamed: 0","region_1"])

# %%
n=  new.rename(columns = {"region_2":"region"})

# %%
n.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region         taster_name taster_twitter_handle  \
# 0                NaN       Kerin O’Keefe          @kerinokeefe
# ...

# %%
g = n.groupby('country')
g

# %%
#for city , city_n in g:
#  print(city)
 #   print(city_n)

# %%
g.get_group("US")        #group of countries
# Out:
#        country                                        description  \
# 2           US  Tart and snappy, the flavors of lime flesh and...
# 3           US  Pineapple rind, lemon pith and orange blossom ...
# 4           US  Much like the regular bottling from 2012, this...
# 10          US  Soft, supple plum envelopes an oaky structure ...
# 12          US  Slightly reduced, this wine offers a chalky, t...
# ...        ...                                                ...
# 129945      US  Hailing from one of the more popular vineyards...
# 129949      US  There's no bones about the use of oak in this ...
# 129950      US  This opens with herbaceous dollops of thyme an...
# 129952      US  This Zinfandel from the eastern section of Nap...
# 129967      US  Citation is given as much as a decade of bottl...
#
#                                designation  points  price    province  \
# 2                                      NaN      87   14.0      Oregon
# ...

# %%
g.get_group("US").shape
# Out:
# (54504, 12)

# %%
g.get_group("Italy").shape
# Out:
# (19540, 12)

# %%
g.get_group("Portugal").shape
# Out:
# (5691, 12)

# %%
g.get_group("Argentina").shape
# Out:
# (3800, 12)

# %%
n["country"]           # for one column
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
n[["country","description"]]  #for two column
# Out:
#          country                                        description
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
# [129971 rows x 2 columns]

# %%
n[["country","description","province"]]  # for two or more individual column
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                  province
# 0       Sicily & Sardinia
# 1                   Douro
# 2                  Oregon
# 3                Michigan
# ...

# %%
n.iloc[5]    # selecting individual row
# Out:
# country                                                              Spain
# description              Blackberry and raspberry aromas show a typical...
# designation                                                   Ars In Vitro
# points                                                                  87
# price                                                                   15
# province                                                    Northern Spain
# region                                                                 NaN
# taster_name                                              Michael Schachner
# taster_twitter_handle                                          @wineschach
# title                    Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...
# variety                                                 Tempranillo-Merlot
# winery                                                              Tandem
# Name: 5, dtype: object

# %%
n.iloc[126548:126552]    # selecting group of row
# Out:
#        country                                        description  \
# 126548  France  This wine comes from a steeply sloping vineyar...
# 126549  France  From vineyards around the town of Rochecorbon ...
# 126550  France  Produced in the typical flinty (silex) soil of...
# 126551  France  This is a newly created estate of 27 acres bas...
#
#                         designation  points  price      province region  \
# 126548        Les Crots Premier Cru      91   70.0      Burgundy    NaN
# 126549                          NaN      91   20.0  Loire Valley    NaN
# 126550  Philippe Girard Cuvée Silex      91   29.0  Loire Valley    NaN
# 126551                          NaN      91    NaN      Burgundy    NaN
#
#        taster_name taster_twitter_handle  \
# 126548  Roger Voss            @vossroger
# 126549  Roger Voss            @vossroger
# 126550  Roger Voss            @vossroger
# 126551  Roger Voss            @vossroger
#
# ...

# %%
n.iloc[126540:126580:10]    # selecting a group of  specific of series
# Out:
#        country                                        description  \
# 126540      US  This wine is half Merlot, with the balance Cab...
# 126550  France  Produced in the typical flinty (silex) soil of...
# 126560  Canada  Rich and concentrated, this uber-reserve offer...
# 126570      US  Fresh aromas of blueberry brioche and blackber...
#
#                         designation  points  price          province  \
# 126540                     Sundance      91   20.0        Washington
# 126550  Philippe Girard Cuvée Silex      91   29.0      Loire Valley
# 126560                     Perpetua      91   50.0  British Columbia
# 126570                Primal Scream      91   60.0        California
#
#                  region       taster_name taster_twitter_handle  \
# 126540  Columbia Valley  Sean P. Sullivan         @wawinereport
# 126550              NaN        Roger Voss            @vossroger
# 126560              NaN      Paul Gregutt           @paulgwine
# ...

# %%
# for rows and column both selecting

# %%
for i in n.iloc[5,2:4]:                     # vertical print
    print(i)
# Out:
# Ars In Vitro
# 87

# %%
 n.iloc[5,2:4]                                # horizontal print
# Out:
# designation    Ars In Vitro
# points                   87
# Name: 5, dtype: object

# %%
n.iloc[500:505,2:4]                # group of rows and column
# Out:
#               designation  points
# 500                Rosado      87
# 501  Silvaspoons Vineyard      87
# 502               Muscato      87
# 503                   NaN      87
# 504  Réserve Grand Veneur      87

# %%
n.iloc[500:600:10,2:4]                  # group of series of rows and column
# Out:
#                                            designation  points
# 500                                             Rosado      87
# 510                                 Coastview Vineyard      91
# 520                     Doux Sawyer Lindquist Vineyard      91
# 530  Cuvée Alexandre Apalta Vineyard Made With Orga...      91
# 540                               Bien Nacido Vineyard      93
# 550                                     Estate Reserve      93
# 560                                   Headpruned Block      93
# 570                              Art Den Hoed Vineyard      89
# 580                                                NaN      89
# 590                                                NaN      89

# %%
list(set(n["country"]))    # for getting unique value in a columns for example countries
# Out:
# [nan,
#  'Slovakia',
#  'France',
#  'Turkey',
#  'Argentina',
#  'Romania',
#  'Morocco',
#  'Peru',
#  'India',
#  'Cyprus',
#  'Canada',
#  'US',
#  'Croatia',
#  'Hungary',
#  'Germany',
#  'Brazil',
#  'Bulgaria',
#  'Lebanon',
#  'Spain',
#  'Luxembourg',
#  'Moldova',
#  'England',
#  'Chile',
#  'Bosnia and Herzegovina',
#  'Slovenia',
#  'Serbia',
#  'Switzerland',
#  'New Zealand',
#  'Portugal',
#  'China',
#  'Georgia',
#  'Austria',
#  'Italy',
#  'Israel',
#  'Greece',
#  'Czech Republic',
#  'Mexico',
#  'Egypt',
#  'Uruguay',
#  'Australia',
#  'South Africa',
#  'Ukraine',
#  'Macedonia',
#  'Armenia']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("sales_data.csv - sales_data.csv")

# %%
data
# Out:
#               Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0       2013-11-26   26  November  2013            19     Youth (<25)
# 1       2015-11-26   26  November  2015            19     Youth (<25)
# 2       2014-03-23   23     March  2014            49  Adults (35-64)
# 3       2016-03-23   23     March  2016            49  Adults (35-64)
# 4       2014-05-15   15       May  2014            47  Adults (35-64)
# ...            ...  ...       ...   ...           ...             ...
# 113031  2016-04-12   12     April  2016            41  Adults (35-64)
# 113032  2014-04-02    2     April  2014            18     Youth (<25)
# 113033  2016-04-02    2     April  2016            18     Youth (<25)
# 113034  2014-03-04    4     March  2014            37  Adults (35-64)
# 113035  2016-03-04    4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %%
list(set(data["Sub_Category"]))
# Out:
# ['Vests',
#  'Mountain Bikes',
#  'Jerseys',
#  'Hydration Packs',
#  'Bottles and Cages',
#  'Helmets',
#  'Cleaners',
#  'Bike Racks',
#  'Shorts',
#  'Tires and Tubes',
#  'Socks',
#  'Bike Stands',
#  'Road Bikes',
#  'Touring Bikes',
#  'Gloves',
#  'Fenders',
#  'Caps']

# %%
list(set(data["Country"]))
# Out:
# ['Germany', 'United States', 'France', 'Canada', 'United Kingdom', 'Australia']

# %%
g = data.groupby("Country")

# %%
germany = g.get_group("Germany")
us = g.get_group("United States")
france = g.get_group("France")
canada = g.get_group("Canada")
uk = g.get_group('United Kingdom')
aus = g.get_group("Australia")
germany
# Out:
#               Date  Day      Month  Year  Customer_Age             Age_Group  \
# 48      2013-08-07    7     August  2013            38        Adults (35-64)
# 49      2015-08-07    7     August  2015            38        Adults (35-64)
# 62      2013-09-25   25  September  2013            19           Youth (<25)
# 63      2015-09-25   25  September  2015            19           Youth (<25)
# 94      2013-09-23   23  September  2013            41        Adults (35-64)
# ...            ...  ...        ...   ...           ...                   ...
# 113007  2016-03-28   28      March  2016            28  Young Adults (25-34)
# 113010  2014-04-10   10      April  2014            25  Young Adults (25-34)
# 113011  2016-04-10   10      April  2016            25  Young Adults (25-34)
# 113026  2013-07-08    8       July  2013            29  Young Adults (25-34)
# 113027  2015-07-08    8       July  2015            29  Young Adults (25-34)
#
# ...

# %%
total_profit_germany = germany["Profit"].sum()                        #how to get sum of a column (grouped sum)
total_profit_us = us["Profit"].sum()
total_profit_france = france["Profit"].sum()
total_profit_canada = canada["Profit"].sum()
total_profit_uk = uk["Profit"].sum()
total_profit_aus = aus["Profit"].sum()



print("total_profit_germany = " ,total_profit_germany)
print("total_profit_us = " ,total_profit_us)
print("total_profit_france = " ,total_profit_france)
print("total_profit_canada = " ,total_profit_canada)
print("total_profit_uk = " ,total_profit_uk)
print("total_profit_aus = " ,total_profit_aus)
# Out:
# total_profit_germany =  3359995
# total_profit_us =  11073644
# total_profit_france =  2880282
# total_profit_canada =  3717296
# total_profit_uk =  4413853
# total_profit_aus =  6776030

# %%
print( "total_profit_germany = " ,total_profit_germany,
            "total_profit_us = " ,total_profit_us,
            "total_profit_france = " ,total_profit_france,
            "total_profit_canada = " ,total_profit_canada,
            "total_profit_uk = " ,total_profit_uk,
            "total_profit_aus = " ,total_profit_aus)
# Out:
# total_profit_germany =  3359995 total_profit_us =  11073644 total_profit_france =  2880282 total_profit_canada =  3717296 total_profit_uk =  4413853 total_profit_aus =  6776030

# %%
bata = pd.read_csv("countries_info.csv")

# %%
bata
# Out:
#        Unnamed: 0    Unnamed: 1         Unnamed: 2      Unnamed: 3  \
# 0             NaN           NaN                NaN             NaN
# 1    Country Name  Country Code     Indicator Name  Indicator Code
# 2           Aruba           ABW  Population, total     SP.POP.TOTL
# 3     Afghanistan           AFG  Population, total     SP.POP.TOTL
# 4          Angola           AGO  Population, total     SP.POP.TOTL
# ..            ...           ...                ...             ...
# 261        Kosovo           XKX  Population, total     SP.POP.TOTL
# 262   Yemen, Rep.           YEM  Population, total     SP.POP.TOTL
# 263  South Africa           ZAF  Population, total     SP.POP.TOTL
# 264        Zambia           ZMB  Population, total     SP.POP.TOTL
# 265      Zimbabwe           ZWE  Population, total     SP.POP.TOTL
#
#      Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0           NaN         NaN         NaN         NaN         NaN         NaN
# ...

# %%
bata.drop( 0 , axis=0 , inplace = True)

# %%
bata
# Out:
#        Unnamed: 0    Unnamed: 1         Unnamed: 2      Unnamed: 3  \
# 1    Country Name  Country Code     Indicator Name  Indicator Code
# 2           Aruba           ABW  Population, total     SP.POP.TOTL
# 3     Afghanistan           AFG  Population, total     SP.POP.TOTL
# 4          Angola           AGO  Population, total     SP.POP.TOTL
# 5         Albania           ALB  Population, total     SP.POP.TOTL
# ..            ...           ...                ...             ...
# 261        Kosovo           XKX  Population, total     SP.POP.TOTL
# 262   Yemen, Rep.           YEM  Population, total     SP.POP.TOTL
# 263  South Africa           ZAF  Population, total     SP.POP.TOTL
# 264        Zambia           ZMB  Population, total     SP.POP.TOTL
# 265      Zimbabwe           ZWE  Population, total     SP.POP.TOTL
#
#      Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 1        1960.0      1961.0      1962.0      1963.0      1964.0      1965.0
# ...

# %%
# Making row 1 as column header there are two ways to do this

# %%
# Way one
#new_header = bata.iloc[0]           #grab the first row for the header
#bata = bata[1:]                 #take the data less the header row
#bata.columns = new_header          #set the header row as the df header

# %%
# Way 2 
mp = bata.rename(columns = bata.iloc[0]).drop(bata.index[0])
mp
# Out:
#      Country Name Country Code     Indicator Name Indicator Code      1960.0  \
# 2           Aruba          ABW  Population, total    SP.POP.TOTL     54211.0
# 3     Afghanistan          AFG  Population, total    SP.POP.TOTL   8996973.0
# 4          Angola          AGO  Population, total    SP.POP.TOTL   5454933.0
# 5         Albania          ALB  Population, total    SP.POP.TOTL   1608800.0
# 6         Andorra          AND  Population, total    SP.POP.TOTL     13411.0
# ..            ...          ...                ...            ...         ...
# 261        Kosovo          XKX  Population, total    SP.POP.TOTL    947000.0
# 262   Yemen, Rep.          YEM  Population, total    SP.POP.TOTL   5315355.0
# 263  South Africa          ZAF  Population, total    SP.POP.TOTL  17099840.0
# 264        Zambia          ZMB  Population, total    SP.POP.TOTL   3070776.0
# 265      Zimbabwe          ZWE  Population, total    SP.POP.TOTL   3776681.0
#
# ...

# %%
mp.head(5)
# Out:
#   Country Name Country Code     Indicator Name Indicator Code     1960.0  \
# 2        Aruba          ABW  Population, total    SP.POP.TOTL    54211.0
# 3  Afghanistan          AFG  Population, total    SP.POP.TOTL  8996973.0
# 4       Angola          AGO  Population, total    SP.POP.TOTL  5454933.0
# 5      Albania          ALB  Population, total    SP.POP.TOTL  1608800.0
# 6      Andorra          AND  Population, total    SP.POP.TOTL    13411.0
#
#       1961.0     1962.0     1963.0     1964.0     1965.0  ...      2010.0  \
# 2    55438.0    56225.0    56695.0    57032.0    57360.0  ...    101669.0
# 3  9169410.0  9351441.0  9543205.0  9744781.0  9956320.0  ...  29185507.0
# 4  5531472.0  5608539.0  5679458.0  5735044.0  5770570.0  ...  23356246.0
# 5  1659800.0  1711319.0  1762621.0  1814135.0  1864791.0  ...   2913021.0
# 6    14375.0    15370.0    16412.0    17469.0    18549.0  ...     84449.0
#
#        2011.0      2012.0      2013.0      2014.0      2015.0      2016.0  \
# ...

# %%
mh = mp.drop(columns = ["Country Code", "Indicator Name","Indicator Code"])

# %%
mh
# Out:
#      Country Name      1960.0      1961.0      1962.0      1963.0      1964.0  \
# 2           Aruba     54211.0     55438.0     56225.0     56695.0     57032.0
# 3     Afghanistan   8996973.0   9169410.0   9351441.0   9543205.0   9744781.0
# 4          Angola   5454933.0   5531472.0   5608539.0   5679458.0   5735044.0
# 5         Albania   1608800.0   1659800.0   1711319.0   1762621.0   1814135.0
# 6         Andorra     13411.0     14375.0     15370.0     16412.0     17469.0
# ..            ...         ...         ...         ...         ...         ...
# 261        Kosovo    947000.0    966000.0    994000.0   1022000.0   1050000.0
# 262   Yemen, Rep.   5315355.0   5393036.0   5473671.0   5556766.0   5641597.0
# 263  South Africa  17099840.0  17524533.0  17965725.0  18423161.0  18896307.0
# 264        Zambia   3070776.0   3164329.0   3260650.0   3360104.0   3463213.0
# 265      Zimbabwe   3776681.0   3905034.0   4039201.0   4178726.0   4322861.0
#
# ...

# %%
data = mh.rename(columns = {"Country Name":"Country"})

# %%
data
# Out:
#           Country      1960.0      1961.0      1962.0      1963.0      1964.0  \
# 2           Aruba     54211.0     55438.0     56225.0     56695.0     57032.0
# 3     Afghanistan   8996973.0   9169410.0   9351441.0   9543205.0   9744781.0
# 4          Angola   5454933.0   5531472.0   5608539.0   5679458.0   5735044.0
# 5         Albania   1608800.0   1659800.0   1711319.0   1762621.0   1814135.0
# 6         Andorra     13411.0     14375.0     15370.0     16412.0     17469.0
# ..            ...         ...         ...         ...         ...         ...
# 261        Kosovo    947000.0    966000.0    994000.0   1022000.0   1050000.0
# 262   Yemen, Rep.   5315355.0   5393036.0   5473671.0   5556766.0   5641597.0
# 263  South Africa  17099840.0  17524533.0  17965725.0  18423161.0  18896307.0
# 264        Zambia   3070776.0   3164329.0   3260650.0   3360104.0   3463213.0
# 265      Zimbabwe   3776681.0   3905034.0   4039201.0   4178726.0   4322861.0
#
# ...

# %%
reset = data.T.reset_index().T
reset
# Out:
#                  0            1            2            3            4   \
# index       Country         1960         1961         1962         1963
# 2             Aruba        54211        55438        56225        56695
# 3       Afghanistan  8.99697e+06  9.16941e+06  9.35144e+06  9.54320e+06
# 4            Angola  5.45493e+06  5.53147e+06  5.60854e+06  5.67946e+06
# 5           Albania   1.6088e+06   1.6598e+06  1.71132e+06  1.76262e+06
# ...             ...          ...          ...          ...          ...
# 261          Kosovo       947000       966000       994000    1.022e+06
# 262     Yemen, Rep.  5.31536e+06  5.39304e+06  5.47367e+06  5.55677e+06
# 263    South Africa  1.70998e+07  1.75245e+07  1.79657e+07  1.84232e+07
# 264          Zambia  3.07078e+06  3.16433e+06  3.26065e+06   3.3601e+06
# 265        Zimbabwe  3.77668e+06  3.90503e+06   4.0392e+06  4.17873e+06
#
#                 5            6            7            8            9   ...  \
# ...

# %%
reset_t = reset.transpose()
reset_t
# Out:
#       index       2            3            4            5        6  \
# 0   Country   Aruba  Afghanistan       Angola      Albania  Andorra
# 1      1960   54211  8.99697e+06  5.45493e+06   1.6088e+06    13411
# 2      1961   55438  9.16941e+06  5.53147e+06   1.6598e+06    14375
# 3      1962   56225  9.35144e+06  5.60854e+06  1.71132e+06    15370
# 4      1963   56695  9.54320e+06  5.67946e+06  1.76262e+06    16412
# ..      ...     ...          ...          ...          ...      ...
# 56     2015  104341  3.44136e+07  2.78844e+07   2.8807e+06    78011
# 57     2016  104872  3.53831e+07  2.88425e+07   2.8761e+06    77297
# 58     2017  105366  3.62964e+07  2.98167e+07  2.87346e+06    77001
# 59     2018  105845  3.71724e+07  3.08098e+07  2.86638e+06    77006
# 60     2019  106314  3.80418e+07  3.18253e+07  2.85419e+06    77142
#
#               7                     8            9           10  ...  \
# 0    Arab World  United Arab Emirates    Argentina      Armenia  ...
# ...

# %%
reset_t.columns
# Out:
# Index(['index',       2,       3,       4,       5,       6,       7,       8,
#              9,      10,
#        ...
#            256,     257,     258,     259,     260,     261,     262,     263,
#            264,     265],
#       dtype='object', length=265)

# %%
p = reset_t.rename(columns = reset_t.iloc[0]).drop(reset_t.index[0])
p
# Out:
#    Country   Aruba  Afghanistan       Angola      Albania Andorra  \
# 1     1960   54211  8.99697e+06  5.45493e+06   1.6088e+06   13411
# 2     1961   55438  9.16941e+06  5.53147e+06   1.6598e+06   14375
# 3     1962   56225  9.35144e+06  5.60854e+06  1.71132e+06   15370
# 4     1963   56695  9.54320e+06  5.67946e+06  1.76262e+06   16412
# 5     1964   57032  9.74478e+06  5.73504e+06  1.81414e+06   17469
# 6     1965   57360  9.95632e+06  5.77057e+06  1.86479e+06   18549
# 7     1966   57715  1.01748e+07  5.78121e+06  1.91457e+06   19647
# 8     1967   58055  1.03999e+07  5.77424e+06   1.9656e+06   20758
# 9     1968   58386  1.06371e+07  5.77165e+06  2.02227e+06   21890
# 10    1969   58726  1.08938e+07  5.80325e+06   2.0817e+06   23058
# 11    1970   59063  1.11736e+07  5.89036e+06  2.13548e+06   24276
# 12    1971   59440  1.14754e+07  6.04078e+06  2.18785e+06   25559
# 13    1972   59840  1.17912e+07  6.24855e+06  2.24313e+06   26892
# ...

# %%
p["Country"]
# Out:
# 1     1960
# 2     1961
# 3     1962
# 4     1963
# 5     1964
# 6     1965
# 7     1966
# 8     1967
# 9     1968
# 10    1969
# 11    1970
# 12    1971
# 13    1972
# 14    1973
# 15    1974
# 16    1975
# 17    1976
# 18    1977
# 19    1978
# 20    1979
# 21    1980
# 22    1981
# 23    1982
# 24    1983
# 25    1984
# 26    1985
# 27    1986
# 28    1987
# 29    1988
# 30    1989
# 31    1990
# 32    1991
# 33    1992
# 34    1993
# 35    1994
# 36    1995
# 37    1996
# 38    1997
# 39    1998
# 40    1999
# 41    2000
# 42    2001
# 43    2002
# 44    2003
# 45    2004
# 46    2005
# 47    2006
# 48    2007
# 49    2008
# 50    2009
# 51    2010
# 52    2011
# 53    2012
# 54    2013
# 55    2014
# 56    2015
# 57    2016
# 58    2017
# 59    2018
# 60    2019
# Name: Country, dtype: object

# %%
f_data = p.rename(columns = { "Country": "Year" , "United States" : "USA"})
f_data
# Out:
#     Year   Aruba  Afghanistan       Angola      Albania Andorra   Arab World  \
# 1   1960   54211  8.99697e+06  5.45493e+06   1.6088e+06   13411  9.21978e+07
# 2   1961   55438  9.16941e+06  5.53147e+06   1.6598e+06   14375  9.47245e+07
# 3   1962   56225  9.35144e+06  5.60854e+06  1.71132e+06   15370  9.73344e+07
# 4   1963   56695  9.54320e+06  5.67946e+06  1.76262e+06   16412  1.00034e+08
# 5   1964   57032  9.74478e+06  5.73504e+06  1.81414e+06   17469  1.02833e+08
# 6   1965   57360  9.95632e+06  5.77057e+06  1.86479e+06   18549  1.05736e+08
# 7   1966   57715  1.01748e+07  5.78121e+06  1.91457e+06   19647  1.08759e+08
# 8   1967   58055  1.03999e+07  5.77424e+06   1.9656e+06   20758  1.11899e+08
# 9   1968   58386  1.06371e+07  5.77165e+06  2.02227e+06   21890  1.15136e+08
# 10  1969   58726  1.08938e+07  5.80325e+06   2.0817e+06   23058  1.18437e+08
# 11  1970   59063  1.11736e+07  5.89036e+06  2.13548e+06   24276  1.21786e+08
# ...

# %%
f_data.columns
# Out:
# Index(['Year', 'Aruba', 'Afghanistan', 'Angola', 'Albania', 'Andorra',
#        'Arab World', 'United Arab Emirates', 'Argentina', 'Armenia',
#        ...
#        'Virgin Islands (U.S.)', 'Vietnam', 'Vanuatu', 'World', 'Samoa',
#        'Kosovo', 'Yemen, Rep.', 'South Africa', 'Zambia', 'Zimbabwe'],
#       dtype='object', length=265)

# %%
x =f_data[["Year","India","China","Indonesia","USA","Pakistan"]]
x
# Out:
#     Year        India        China    Indonesia          USA     Pakistan
# 1   1960  4.50548e+08   6.6707e+08  8.77511e+07  1.80671e+08  4.49887e+07
# 2   1961  4.59642e+08   6.6033e+08  9.00984e+07  1.83691e+08  4.60652e+07
# 3   1962  4.69077e+08   6.6577e+08  9.25184e+07  1.86538e+08  4.71989e+07
# 4   1963  4.78826e+08  6.82335e+08  9.50153e+07  1.89242e+08  4.83873e+07
# 5   1964  4.88848e+08  6.98355e+08  9.75967e+07  1.91889e+08  4.96276e+07
# 6   1965  4.99123e+08  7.15185e+08  1.00267e+08  1.94303e+08   5.0918e+07
# 7   1966  5.09632e+08    7.354e+08  1.03025e+08   1.9656e+08  5.22602e+07
# 8   1967  5.20401e+08   7.5455e+08  1.05866e+08  1.98712e+08  5.36558e+07
# 9   1968  5.31514e+08   7.7451e+08   1.0878e+08  2.00706e+08  5.51027e+07
# 10  1969  5.43084e+08  7.96025e+08  1.11759e+08  2.02677e+08  5.65981e+07
# 11  1970   5.5519e+08  8.18315e+08  1.14793e+08  2.05052e+08  5.81421e+07
# 12  1971  5.67868e+08  8.41105e+08   1.1788e+08  2.07661e+08  5.97345e+07
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(f_data.Year , f_data.India/10**7 )
plt.plot(f_data.Year , f_data.China/10**7 )
plt.plot(f_data.Year , f_data.USA/10**7 )
plt.plot(f_data.Year , f_data.Indonesia/10**7)
plt.plot(f_data.Year , f_data.Pakistan/10**7 )
plt.legend(["India","China","USA","Indonesia","Pakistan"])
plt.xlabel(" Year ")
plt.ylabel(" Population in crores")
plt.title("  Top five populated countries ")
plt.show()

# %%
fig , ax = plt.subplots()
ax.bar(f_data["Year"] , f_data["India"]/10**7)
plt.xlabel(" Year ")
plt.ylabel(" INDIA's Population(cr)")


plt.show()

# %%
fig , ax = plt.subplots()
ax.bar(f_data["Year"] , f_data["China"]/10**7 , color = "red")
plt.ylabel(" CHINA's Population(cr)")
plt.xlabel(" Year ")
plt.show()

# %%
fig , ax = plt.subplots()
ax.bar(f_data["Year"] , f_data["China"]/10**7 , color = "red")
plt.ylabel(" Population in crores")
plt.xlabel(" Year ")
plt.show()

# %%
fig , ax = plt.subplots()
ax.bar(f_data["Year"] , f_data["Pakistan"]/10**7 , color = "green")
plt.ylabel(" Pakistan's Population(cr) ")
plt.xlabel(" Year ")
plt.show()

# %%
fig , ax = plt.subplots()
ax.bar(f_data["Year"] , f_data["Indonesia"]/10**7 , color = "grey")
plt.ylabel(" INDINESIA'S Population(cr)")
plt.xlabel(" Year ")
plt.show()

# %%
import pandas as pd
from bokeh.plotting import figure, show

# %%
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
melted_y = pd.melt(y, id_vars=['Year'], value_vars=['India', 'China'])
melted_y.head()
# Out:
#    Year variable        value
# 0  1960    India  4.50548e+08
# 1  1961    India  4.59642e+08
# 2  1962    India  4.69077e+08
# 3  1963    India  4.78826e+08
# 4  1964    India  4.88848e+08

# %%
bk = Bar(melted_y, label="Year", values="value", group="variable", legend="top_left", ylabel='Population in crore')
show(bk)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-f1dd0d730a74> in <module>
# ----> 1 bk = Bar(melted_y, label="Year", values="value", group="variable", legend="top_left", ylabel='Population in crore')
#       2 show(bk)
#
# NameError: name 'Bar' is not defined

# %%
c  = pd.read_csv("countries.csv")
c
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# ...           ...   ...         ...
# 1699     Zimbabwe  1987     9216418
# 1700     Zimbabwe  1992    10704340
# 1701     Zimbabwe  1997    11404948
# 1702     Zimbabwe  2002    11926563
# 1703     Zimbabwe  2007    12311143
#
# [1704 rows x 3 columns]

# %%
ind = c[c.country == "India"]

# %%
ind
# Out:
#     country  year  population
# 696   India  1952   372000000
# 697   India  1957   409000000
# 698   India  1962   454000000
# 699   India  1967   506000000
# 700   India  1972   567000000
# 701   India  1977   634000000
# 702   India  1982   708000000
# 703   India  1987   788000000
# 704   India  1992   872000000
# 705   India  1997   959000000
# 706   India  2002  1034172547
# 707   India  2007  1110396331

# %%
ch = c[c.country == "China"]
ch
# Out:
#     country  year  population
# 288   China  1952   556263527
# 289   China  1957   637408000
# 290   China  1962   665770000
# 291   China  1967   754550000
# 292   China  1972   862030000
# 293   China  1977   943455000
# 294   China  1982  1000281000
# 295   China  1987  1084035000
# 296   China  1992  1164970000
# 297   China  1997  1230075000
# 298   China  2002  1280400000
# 299   China  2007  1318683096

# %%
plt.plot(ind.year , ind.population/10**7)
plt.plot(ch.year , ch.population/10**7)
plt.legend(["INDIA ", "CHINA"])
plt.xlabel("YEAR")
plt.ylabel("Population in crore")
plt.show()
